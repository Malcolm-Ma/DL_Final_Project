# %%
import os
import numpy as np
import pandas as pd
import scipy.io
import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.models import *
from keras.layers import *
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import *
from keras.layers.pooling import MaxPooling2D
from keras.optimizers import *
from keras.layers.merge import concatenate
from keras import backend as K
import tensorflow as tf

# %%
print(os.listdir("../input"))
# Out:
# ['.DS_Store', '._.DS_Store', '2015_BOE_Chiu']

# %%
input_path = os.path.join('..', 'input', '2015_BOE_Chiu', '2015_BOE_Chiu')
subject_path = [os.path.join(input_path, 'Subject_0{}.mat'.format(i)) for i in range(1, 10)] + [os.path.join(input_path, 'Subject_10.mat')]

data_indexes = [10, 15, 20, 25, 28, 30, 32, 35, 40, 45, 50]

width = 768
height = 496

# %%
mat = scipy.io.loadmat(subject_path[0])
img_tensor = mat['images']
manual_fluid_tensor_1 = mat['manualFluid1']

img_array = np.transpose(img_tensor, (2, 0, 1))
manual_fluid_array = np.transpose(manual_fluid_tensor_1, (2, 0, 1))

# %%
plt.imshow(img_array[32])

# %%
plt.imshow(manual_fluid_array[32])

# %%
def thresh(x):
    if x == 0:
        return 0
    else:
        return 1

thresh = np.vectorize(thresh, otypes=[np.float])

def create_dataset(paths):
    x = []
    y = []
    
    for path in paths:
        mat = scipy.io.loadmat(path)
        img_tensor = mat['images']
        fluid_tensor = mat['manualFluid1']
        
        img_array = np.transpose(img_tensor, (2, 0 ,1)) / 255
        fluid_array = np.transpose(fluid_tensor, (2, 0 ,1))
        fluid_array = thresh(fluid_array)
        
        for idx in data_indexes:
            x += [np.expand_dims(img_array[idx], 2)]
            y += [np.expand_dims(fluid_array[idx], 2)]
        
    return np.array(x), np.array(y)

x_train, y_train = create_dataset(subject_path[:9])
x_val, y_val = create_dataset(subject_path[9:])

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((99, 496, 768, 1), (99, 496, 768, 1), (11, 496, 768, 1), (11, 496, 768, 1))

# %%
input_size = (height,width,1)

inputs = Input(input_size)
conv1 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
conv1 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
conv2 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
conv3 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
conv4 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
# pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
drop5 = Dropout(0.5)(conv5)

up6 = Conv2D(24, (2, 2), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size=(2,2))(drop5))
# up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(drop5)
# up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(conv5)
merge6 = concatenate([drop4, up6], axis=3)
# merge6 = concatenate([conv4, up6])
conv6 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
conv6 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

up7 = Conv2D(16, (2, 2), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size=(2,2))(conv6))
merge7 = concatenate([conv3,up7], axis=3)
conv7 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
conv7 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

up8 = Conv2D(12, (2, 2), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size=(2,2))(conv7))
merge8 = concatenate([conv2,up8], axis=3)
conv8 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
conv8 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

up9 = Conv2D(8, (2, 2), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size=(2,2))(conv8))
merge9 = concatenate([conv1,up9], axis=3)
conv9 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
conv9 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = Conv2D(2, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[outputs])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_28 (InputLayer)           (None, 496, 768, 1)  0
# __________________________________________________________________________________________________
# conv2d_496 (Conv2D)             (None, 496, 768, 8)  80          input_28[0][0]
# __________________________________________________________________________________________________
# conv2d_497 (Conv2D)             (None, 496, 768, 8)  584         conv2d_496[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_109 (MaxPooling2D (None, 248, 384, 8)  0           conv2d_497[0][0]
# __________________________________________________________________________________________________
# conv2d_498 (Conv2D)             (None, 248, 384, 12) 876         max_pooling2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_499 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_498[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_110 (MaxPooling2D (None, 124, 192, 12) 0           conv2d_499[0][0]
# __________________________________________________________________________________________________
# conv2d_500 (Conv2D)             (None, 124, 192, 16) 1744        max_pooling2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_501 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_500[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_111 (MaxPooling2D (None, 62, 96, 16)   0           conv2d_501[0][0]
# __________________________________________________________________________________________________
# conv2d_502 (Conv2D)             (None, 62, 96, 24)   3480        max_pooling2d_111[0][0]
# __________________________________________________________________________________________________
# conv2d_503 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_502[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 62, 96, 24)   0           conv2d_503[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_112 (MaxPooling2D (None, 31, 48, 24)   0           dropout_33[0][0]
# __________________________________________________________________________________________________
# conv2d_504 (Conv2D)             (None, 31, 48, 32)   6944        max_pooling2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_505 (Conv2D)             (None, 31, 48, 32)   9248        conv2d_504[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 31, 48, 32)   0           conv2d_505[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_35 (UpSampling2D) (None, 62, 96, 32)   0           dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_506 (Conv2D)             (None, 62, 96, 24)   3096        up_sampling2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_83 (Concatenate)    (None, 62, 96, 48)   0           dropout_33[0][0]
#                                                                  conv2d_506[0][0]
# __________________________________________________________________________________________________
# conv2d_507 (Conv2D)             (None, 62, 96, 24)   10392       concatenate_83[0][0]
# __________________________________________________________________________________________________
# conv2d_508 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_507[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_36 (UpSampling2D) (None, 124, 192, 24) 0           conv2d_508[0][0]
# __________________________________________________________________________________________________
# conv2d_509 (Conv2D)             (None, 124, 192, 16) 1552        up_sampling2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_84 (Concatenate)    (None, 124, 192, 32) 0           conv2d_501[0][0]
#                                                                  conv2d_509[0][0]
# __________________________________________________________________________________________________
# conv2d_510 (Conv2D)             (None, 124, 192, 16) 4624        concatenate_84[0][0]
# __________________________________________________________________________________________________
# conv2d_511 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_510[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 248, 384, 16) 0           conv2d_511[0][0]
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, 248, 384, 12) 780         up_sampling2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_85 (Concatenate)    (None, 248, 384, 24) 0           conv2d_499[0][0]
#                                                                  conv2d_512[0][0]
# __________________________________________________________________________________________________
# conv2d_513 (Conv2D)             (None, 248, 384, 12) 2604        concatenate_85[0][0]
# __________________________________________________________________________________________________
# conv2d_514 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_513[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 496, 768, 12) 0           conv2d_514[0][0]
# __________________________________________________________________________________________________
# conv2d_515 (Conv2D)             (None, 496, 768, 8)  392         up_sampling2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_86 (Concatenate)    (None, 496, 768, 16) 0           conv2d_497[0][0]
#                                                                  conv2d_515[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 496, 768, 8)  1160        concatenate_86[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 496, 768, 8)  584         conv2d_516[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, 496, 768, 2)  146         conv2d_517[0][0]
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, 496, 768, 1)  3           conv2d_518[0][0]
# ==================================================================================================
# Total params: 65,961
# Trainable params: 65,961
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# input_size = (height,width,1)

# inputs = Input(input_size)
# conv1 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
# conv1 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
# pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

# conv2 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
# conv2 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
# pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

# conv3 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
# conv3 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
# pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

# conv4 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
# conv4 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
# # drop4 = Dropout(0.5)(conv4)
# # pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
# pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

# conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
# conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
# # drop5 = Dropout(0.5)(conv5)

# # up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(drop5)
# up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(conv5)
# # merge6 = concatenate([drop4, up6])
# merge6 = concatenate([conv4, up6])
# conv6 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
# conv6 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

# up7 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(conv6)
# merge7 = concatenate([conv3,up7])
# conv7 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
# conv7 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

# up8 = Conv2DTranspose(12, (2, 2), strides=(2, 2), padding='same')(conv7)
# merge8 = concatenate([conv2,up8])
# conv8 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
# conv8 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

# up9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(conv8)
# merge9 = concatenate([conv1,up9])
# conv9 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
# conv9 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
# conv9 = Conv2D(2, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

# outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

# model = Model(inputs=[inputs], outputs=[outputs])

# model.compile(optimizer=Adam(lr = 1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           (None, 496, 768, 1)  0
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 496, 768, 8)  80          input_21[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 496, 768, 8)  584         conv2d_339[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_81 (MaxPooling2D) (None, 248, 384, 8)  0           conv2d_340[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 248, 384, 12) 876         max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_341[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_82 (MaxPooling2D) (None, 124, 192, 12) 0           conv2d_342[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 124, 192, 16) 1744        max_pooling2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_343[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_83 (MaxPooling2D) (None, 62, 96, 16)   0           conv2d_344[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 62, 96, 24)   3480        max_pooling2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_345[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_84 (MaxPooling2D) (None, 31, 48, 24)   0           conv2d_346[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 31, 48, 32)   6944        max_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 31, 48, 32)   9248        conv2d_347[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_41 (Conv2DTran (None, 62, 96, 24)   3096        conv2d_348[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 62, 96, 48)   0           conv2d_346[0][0]
#                                                                  conv2d_transpose_41[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 62, 96, 24)   10392       concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_349[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_42 (Conv2DTran (None, 124, 192, 16) 1552        conv2d_350[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 124, 192, 32) 0           conv2d_344[0][0]
#                                                                  conv2d_transpose_42[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 124, 192, 16) 4624        concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_351[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_43 (Conv2DTran (None, 248, 384, 12) 780         conv2d_352[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 248, 384, 24) 0           conv2d_342[0][0]
#                                                                  conv2d_transpose_43[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 248, 384, 12) 2604        concatenate_57[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_353[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_44 (Conv2DTran (None, 496, 768, 8)  392         conv2d_354[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 496, 768, 16) 0           conv2d_340[0][0]
#                                                                  conv2d_transpose_44[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 496, 768, 8)  1160        concatenate_58[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 496, 768, 8)  584         conv2d_355[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 496, 768, 2)  146         conv2d_356[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 496, 768, 1)  3           conv2d_357[0][0]
# ==================================================================================================
# Total params: 65,961
# Trainable params: 65,961
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_size = (height,width,1)

inputs = Input(input_size)
conv1 = Conv2D(8, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
conv1 = Conv2D(8, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(12, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
conv2 = Conv2D(12, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(16, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
conv3 = Conv2D(16, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(24, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
conv4 = Conv2D(24, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
# drop4 = Dropout(0.5)(conv4)
# pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(32, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
conv5 = Conv2D(32, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
# drop5 = Dropout(0.5)(conv5)

# up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(drop5)
up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(conv5)
# merge6 = concatenate([drop4, up6])
merge6 = concatenate([conv4, up6])
conv6 = Conv2D(24, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
conv6 = Conv2D(24, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

up7 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(conv6)
merge7 = concatenate([conv3,up7])
conv7 = Conv2D(16, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
conv7 = Conv2D(16, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

up8 = Conv2DTranspose(12, (2, 2), strides=(2, 2), padding='same')(conv7)
merge8 = concatenate([conv2,up8])
conv8 = Conv2D(12, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
conv8 = Conv2D(12, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

up9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(conv8)
merge9 = concatenate([conv1,up9])
conv9 = Conv2D(8, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
conv9 = Conv2D(8, (3, 3), activation = 'elu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[outputs])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_27 (InputLayer)           (None, 496, 768, 1)  0
# __________________________________________________________________________________________________
# conv2d_477 (Conv2D)             (None, 496, 768, 8)  80          input_27[0][0]
# __________________________________________________________________________________________________
# conv2d_478 (Conv2D)             (None, 496, 768, 8)  584         conv2d_477[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_105 (MaxPooling2D (None, 248, 384, 8)  0           conv2d_478[0][0]
# __________________________________________________________________________________________________
# conv2d_479 (Conv2D)             (None, 248, 384, 12) 876         max_pooling2d_105[0][0]
# __________________________________________________________________________________________________
# conv2d_480 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_479[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_106 (MaxPooling2D (None, 124, 192, 12) 0           conv2d_480[0][0]
# __________________________________________________________________________________________________
# conv2d_481 (Conv2D)             (None, 124, 192, 16) 1744        max_pooling2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_482 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_481[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_107 (MaxPooling2D (None, 62, 96, 16)   0           conv2d_482[0][0]
# __________________________________________________________________________________________________
# conv2d_483 (Conv2D)             (None, 62, 96, 24)   3480        max_pooling2d_107[0][0]
# __________________________________________________________________________________________________
# conv2d_484 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_483[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_108 (MaxPooling2D (None, 31, 48, 24)   0           conv2d_484[0][0]
# __________________________________________________________________________________________________
# conv2d_485 (Conv2D)             (None, 31, 48, 32)   6944        max_pooling2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_486 (Conv2D)             (None, 31, 48, 32)   9248        conv2d_485[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_45 (Conv2DTran (None, 62, 96, 24)   3096        conv2d_486[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 62, 96, 48)   0           conv2d_484[0][0]
#                                                                  conv2d_transpose_45[0][0]
# __________________________________________________________________________________________________
# conv2d_487 (Conv2D)             (None, 62, 96, 24)   10392       concatenate_79[0][0]
# __________________________________________________________________________________________________
# conv2d_488 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_487[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_46 (Conv2DTran (None, 124, 192, 16) 1552        conv2d_488[0][0]
# __________________________________________________________________________________________________
# concatenate_80 (Concatenate)    (None, 124, 192, 32) 0           conv2d_482[0][0]
#                                                                  conv2d_transpose_46[0][0]
# __________________________________________________________________________________________________
# conv2d_489 (Conv2D)             (None, 124, 192, 16) 4624        concatenate_80[0][0]
# __________________________________________________________________________________________________
# conv2d_490 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_489[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_47 (Conv2DTran (None, 248, 384, 12) 780         conv2d_490[0][0]
# __________________________________________________________________________________________________
# concatenate_81 (Concatenate)    (None, 248, 384, 24) 0           conv2d_480[0][0]
#                                                                  conv2d_transpose_47[0][0]
# __________________________________________________________________________________________________
# conv2d_491 (Conv2D)             (None, 248, 384, 12) 2604        concatenate_81[0][0]
# __________________________________________________________________________________________________
# conv2d_492 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_491[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_48 (Conv2DTran (None, 496, 768, 8)  392         conv2d_492[0][0]
# __________________________________________________________________________________________________
# concatenate_82 (Concatenate)    (None, 496, 768, 16) 0           conv2d_478[0][0]
#                                                                  conv2d_transpose_48[0][0]
# __________________________________________________________________________________________________
# conv2d_493 (Conv2D)             (None, 496, 768, 8)  1160        concatenate_82[0][0]
# __________________________________________________________________________________________________
# conv2d_494 (Conv2D)             (None, 496, 768, 8)  584         conv2d_493[0][0]
# __________________________________________________________________________________________________
# conv2d_495 (Conv2D)             (None, 496, 768, 1)  9           conv2d_494[0][0]
# ==================================================================================================
# Total params: 65,821
# Trainable params: 65,821
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# from keras.utils.vis_utils import plot_model

# plot_model(model, to_file='model1.png', show_shapes=True)

# %%
# model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
# model.fit(x_train, y_train,steps_per_epoch=300,epochs=1,callbacks=[model_checkpoint])

from keras.callbacks import EarlyStopping

results = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=11, epochs=20)
# Out:
# Train on 99 samples, validate on 11 samples
# Epoch 1/20
# 99/99 [==============================] - ETA: 4s - loss: 0.6275 - accuracy: 0.81 - ETA: 3s - loss: 0.6489 - accuracy: 0.72 - ETA: 3s - loss: 0.6473 - accuracy: 0.72 - ETA: 2s - loss: 0.6564 - accuracy: 0.67 - ETA: 2s - loss: 0.6682 - accuracy: 0.63 - ETA: 1s - loss: 0.6805 - accuracy: 0.58 - ETA: 1s - loss: 0.6776 - accuracy: 0.59 - ETA: 0s - loss: 0.6792 - accuracy: 0.58 - 5s 49ms/step - loss: 0.6745 - accuracy: 0.6009 - val_loss: 0.5559 - val_accuracy: 0.9889
# Epoch 2/20
# 99/99 [==============================] - ETA: 4s - loss: 0.
20
# 99/99 [==============================] - ETA: 4s - loss: 0.6941 - accuracy: 0.54 - ETA: 3s - loss: 0.6742 - accuracy: 0.58 - ETA: 3s - loss: 0.6672 - accuracy: 0.60 - ETA: 2s - loss: 0.6451 - accuracy: 0.65 - ETA: 2s - loss: 0.6488 - accuracy: 0.65 - ETA: 1s - loss: 0.6507 - accuracy: 0.63 - ETA: 1s - loss: 0.6598 - accuracy: 0.61 - ETA: 0s - loss: 0.6620 - accuracy: 0.60 - 5s 49ms/step - loss: 0.6633 - accuracy: 0.6009 - val_loss: 0.4964 - val_accuracy: 0.9889
# Epoch 20/20
# 99/99 [==============================] - ETA: 4s - loss: 0.6727 - accuracy: 0.54 - ETA: 3s - loss: 0.6532 - accuracy: 0.58 - ETA: 3s - loss: 0.6403 - accuracy: 0.63 - ETA: 2s - loss: 0.6610 - accuracy: 0.58 - ETA: 2s - loss: 0.6510 - accuracy: 0.61 - ETA: 1s - loss: 0.6416 - accuracy: 0.63 - ETA: 1s - loss: 0.6423 - accuracy: 0.63 - ETA: 0s - loss: 0.6513 - accuracy: 0.61 - 5s 49ms/step - loss: 0.6656 - accuracy: 0.6009 - val_loss: 0.5039 - val_accuracy: 0.9889

# %%
pred = model.predict(x_val)

# %%
pred = (pred > 0.5).astype(np.uint8)

# %%
nrows = 6

fig, axes = plt.subplots(nrows=nrows, ncols=3, figsize=(15, 10))
for i in range(nrows):
    axes[i][0].imshow(np.reshape(x_val[2*i], (496, 768)))
    axes[i][1].imshow(np.reshape(y_val[2*i], (496, 768)))
    axes[i][2].imshow(np.reshape(pred[2*i], (496, 768)))

plt.show()

# %%
model.evaluate(x_val, y_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d6b12f21092> in <module>
# ----> 1 model.evaluate(x_val, y_val)
#
# NameError: name 'model' is not defined

# %%
plt.imshow(np.reshape(x_val[10], (496, 768)), cmap='Greys_r')

# %%
plt.imshow(np.reshape(y_val[10], (496, 768)), cmap='Greys_r')

# %%
plt.imshow(np.reshape(pred[10], (496, 768)), cmap='Greys_r')

# %%
acc = results.history['accuracy']
val_acc = results.history['val_accuracy']
loss = results.history['loss']
val_loss = results.history['val_loss']
epochs = range(1, len(acc) + 1)

fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.plot(epochs, acc, 'ro', label='Training acc')
ax.plot(epochs, val_acc, 'b', label='Validation acc')
ax.set_title('Accuracy without data augmentation', fontsize=22)
ax.set_xlabel(r'Epochs', fontsize=22)
ax.set_ylabel(r'Accuracy', fontsize=22)
ax.tick_params(labelsize=22)
ax.legend(fontsize=24)

figL, axL = plt.subplots(1,1, figsize=(10,6))

axL.plot(epochs, loss, 'ro', label='Training loss')
axL.plot(epochs, val_loss, 'b', label='Validation loss')
axL.set_title('Loss without data augmentation', fontsize=22)
axL.set_xlabel(r'Epochs', fontsize=22)
axL.set_ylabel(r'Loss', fontsize=22)
axL.tick_params(labelsize=22)
axL.legend(fontsize=22)
