# %%
import os
import numpy as np
import pandas as pd
import scipy.io
import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras import backend as K
import tensorflow as tf

# %%
print(os.listdir("../input"))
# Out:
# ['.DS_Store', '2015_BOE_Chiu']

# %%
input_path = os.path.join('..', 'input', '2015_BOE_Chiu', '2015_BOE_Chiu')
subject_path = [os.path.join(input_path, 'Subject_0{}.mat'.format(i)) for i in range(1, 10)] + [os.path.join(input_path, 'Subject_10.mat')]

data_indexes = [10, 15, 20, 25, 28, 30, 32, 35, 40, 45, 50]

width = 768
height = 496

# %%
mat = scipy.io.loadmat(subject_path[0])
img_tensor = mat['images']
manual_fluid_tensor_1 = mat['manualFluid1']

img_array = np.transpose(img_tensor, (2, 0, 1))
manual_fluid_array = np.transpose(manual_fluid_tensor_1, (2, 0, 1))

# %%
plt.imshow(img_array[32])

# %%
plt.imshow(manual_fluid_array[32])

# %%
def thresh(x):
    if x == 0:
        return 0
    else:
        return 1

thresh = np.vectorize(thresh, otypes=[np.float])

def create_dataset(paths):
    x = []
    y = []
    
    for path in paths:
        mat = scipy.io.loadmat(path)
        img_tensor = mat['images']
        fluid_tensor = mat['manualFluid1']
        
        img_array = np.transpose(img_tensor, (2, 0 ,1)) / 255
        fluid_array = np.transpose(fluid_tensor, (2, 0 ,1))
        fluid_array = thresh(fluid_array)
        
        for idx in data_indexes:
            x += [np.expand_dims(img_array[idx], 2)]
            y += [np.expand_dims(fluid_array[idx], 2)]
        
    return np.array(x), np.array(y)

x_train, y_train = create_dataset(subject_path[:9])
x_val, y_val = create_dataset(subject_path[9:])

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((99, 496, 768, 1), (99, 496, 768, 1), (11, 496, 768, 1), (11, 496, 768, 1))

# %%
input_size = (height,width,1)

inputs = Input(input_size)
conv1 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
conv1 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
conv2 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
conv3 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
conv4 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
conv5 = Conv2D(32, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
drop5 = Dropout(0.5)(conv5)

up6 = Conv2DTranspose(24, (2, 2), strides=(2, 2), padding='same')(drop5)
merge6 = concatenate([drop4, up6])
conv6 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
conv6 = Conv2D(24, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

up7 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(conv6)
merge7 = concatenate([conv3,up7])
conv7 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
conv7 = Conv2D(16, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

up8 = Conv2DTranspose(12, (2, 2), strides=(2, 2), padding='same')(conv7)
merge8 = concatenate([conv2,up8])
conv8 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
conv8 = Conv2D(12, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

up9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(conv8)
merge9 = concatenate([conv1,up9])
conv9 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
conv9 = Conv2D(8, (3, 3), activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[outputs])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 496, 768, 1)  0
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 496, 768, 8)  80          input_14[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 496, 768, 8)  584         conv2d_228[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 248, 384, 8)  0           conv2d_229[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 248, 384, 12) 876         max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_230[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 124, 192, 12) 0           conv2d_231[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 124, 192, 16) 1744        max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_232[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 62, 96, 16)   0           conv2d_233[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 62, 96, 24)   3480        max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_234[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 62, 96, 24)   0           conv2d_235[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 31, 48, 24)   0           dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 31, 48, 32)   6944        max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 31, 48, 32)   9248        conv2d_236[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 31, 48, 32)   0           conv2d_237[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 62, 96, 24)   3096        dropout_24[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 62, 96, 48)   0           dropout_23[0][0]
#                                                                  conv2d_transpose_29[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 62, 96, 24)   10392       concatenate_42[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 62, 96, 24)   5208        conv2d_238[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_30 (Conv2DTran (None, 124, 192, 16) 1552        conv2d_239[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 124, 192, 32) 0           conv2d_233[0][0]
#                                                                  conv2d_transpose_30[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 124, 192, 16) 4624        concatenate_43[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 124, 192, 16) 2320        conv2d_240[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 248, 384, 12) 780         conv2d_241[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 248, 384, 24) 0           conv2d_231[0][0]
#                                                                  conv2d_transpose_31[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 248, 384, 12) 2604        concatenate_44[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 248, 384, 12) 1308        conv2d_242[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_32 (Conv2DTran (None, 496, 768, 8)  392         conv2d_243[0][0]
# __________________________________________________________________________________________________
# concatenate_45 (Concatenate)    (None, 496, 768, 16) 0           conv2d_229[0][0]
#                                                                  conv2d_transpose_32[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 496, 768, 8)  1160        concatenate_45[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 496, 768, 8)  584         conv2d_244[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 496, 768, 2)  146         conv2d_245[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 496, 768, 1)  3           conv2d_246[0][0]
# ==================================================================================================
# Total params: 65,961
# Trainable params: 65,961
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model1.png', show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-86-613988b59a2a> in <module>
#       1 from keras.utils.vis_utils import plot_model
#       2
# ----> 3 plot_model(model, to_file='model1.png', show_shapes=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     238     """
#     239     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir,
# --> 240                        expand_nested, dpi)
#     241     _, extension = os.path.splitext(to_file)
#     242     if not extension:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#      77     from ..models import Sequential
#      78
# ---> 79     _check_pydot()
#      80     if subgraph:
#      81         dot = pydot.Cluster(style='dashed', graph_name=model.name)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      20     if pydot is None:
#      21         raise ImportError(
# ---> 22             'Failed to import `pydot`. '
#      23             'Please install `pydot`. '
#      24             'For example with `pip install pydot`.')
#
# ImportError: Failed to import `pydot`. Please install `pydot`. For example with `pip install pydot`.

# %%
# model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
# model.fit(x_train, y_train,steps_per_epoch=300,epochs=1,callbacks=[model_checkpoint])
results = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=11, epochs=10)
# Out:
# Train on 99 samples, validate on 11 samples
# Epoch 1/10
# 99/99 [==============================] - ETA: 44s - loss: 0.6775 - accuracy: 0.726 - ETA: 21s - loss: 0.7009 - accuracy: 0.504 - ETA: 12s - loss: 0.6992 - accuracy: 0.489 - ETA: 8s - loss: 0.6990 - accuracy: 0.481 - ETA: 5s - loss: 0.6990 - accuracy: 0.47 - ETA: 3s - loss: 0.7017 - accuracy: 0.43 - ETA: 2s - loss: 0.7030 - accuracy: 0.39 - ETA: 1s - loss: 0.7026 - accuracy: 0.39 - 9s 94ms/step - loss: 0.7017 - accuracy: 0.4033 - val_loss: 0.7041 - val_accuracy: 0.2102
# Epoch 2/10
# 99/99 [==============================] - ETA: 3s - loss: 0.6934 - accuracy: 0.49 - ETA: 2s - loss: 0.6936 - accuracy: 0.49 - ETA: 2s - loss: 0.6933 - accuracy: 0.49 - ETA: 2s - loss: 0.6933 - accuracy: 0.48 - ETA: 1s - loss: 0.6934 - accuracy: 0.52 - ETA: 1s - loss: 0.6933 - accuracy: 0.51 - ETA: 0s - loss: 0.6933 - accuracy: 0.53 - ETA: 0s - loss: 0.6932 - accuracy: 0.54 - 4s 40ms/step - loss: 0.6931 - accuracy: 0.5628 - val_loss: 0.6905 - val_accuracy: 0.9214
# Epoch 3/10
# 99/99 [==============================] - ETA: 3s - loss: 0.6912 - accuracy: 0.79 - ETA: 2s - loss: 0.6921 - accuracy: 0.66 - ETA: 2s - loss: 0.6924 - accuracy: 0.61 - ETA: 2s - loss: 0.6927 - accuracy: 0.57 - ETA: 1s - loss: 0.6929 - accuracy: 0.55 - ETA: 1s - loss: 0.6927 - accuracy: 0.56 - ETA: 0s - loss: 0.6926 - accuracy: 0.57 - ETA: 0s - loss: 0.6923 - accuracy: 0.59 - 4s 40ms/step - loss: 0.6922 - accuracy: 0.5956 - val_loss: 0.6871 - val_accuracy: 0.9791
# Epoch 4/10
# 99/99 [==============================] - ETA: 3s - loss: 0.
10
# 99/99 [==============================] - ETA: 3s - loss: 0.6828 - accuracy: 0.81 - ETA: 2s - loss: 0.6843 - accuracy: 0.76 - ETA: 2s - loss: 0.6889 - accuracy: 0.63 - ETA: 2s - loss: 0.6889 - accuracy: 0.63 - ETA: 1s - loss: 0.6889 - accuracy: 0.63 - ETA: 1s - loss: 0.6883 - accuracy: 0.64 - ETA: 0s - loss: 0.6902 - accuracy: 0.59 - ETA: 0s - loss: 0.6896 - accuracy: 0.60 - 4s 40ms/step - loss: 0.6898 - accuracy: 0.6008 - val_loss: 0.6748 - val_accuracy: 0.9875
# Epoch 9/10
# 99/99 [==============================] - ETA: 3s - loss: 0.6848 - accuracy: 0.72 - ETA: 2s - loss: 0.6848 - accuracy: 0.72 - ETA: 2s - loss: 0.6883 - accuracy: 0.63 - ETA: 2s - loss: 0.6892 - accuracy: 0.60 - ETA: 1s - loss: 0.6882 - accuracy: 0.63 - ETA: 1s - loss: 0.6882 - accuracy: 0.63 - ETA: 0s - loss: 0.6887 - accuracy: 0.61 - ETA: 0s - loss: 0.6900 - accuracy: 0.58 - 4s 40ms/step - loss: 0.6893 - accuracy: 0.6009 - val_loss: 0.6725 - val_accuracy: 0.9876
# Epoch 10/10
# 99/99 [==============================] - ETA: 3s - loss: 0.6916 - accuracy: 0.54 - ETA: 2s - loss: 0.6936 - accuracy: 0.49 - ETA: 2s - loss: 0.6916 - accuracy: 0.54 - ETA: 2s - loss: 0.6916 - accuracy: 0.54 - ETA: 1s - loss: 0.6884 - accuracy: 0.61 - ETA: 1s - loss: 0.6862 - accuracy: 0.66 - ETA: 0s - loss: 0.6870 - accuracy: 0.64 - ETA: 0s - loss: 0.6881 - accuracy: 0.61 - 4s 40ms/step - loss: 0.6889 - accuracy: 0.6009 - val_loss: 0.6703 - val_accuracy: 0.9878

# %%
pred = model.predict(x_val)

# %%
pred = (pred > 0.5).astype(np.uint8)

# %%
nrows = 6
fig, axes = plt.subplots(nrows=nrows, ncols=3, figsize=(15, 10))
for i in range(nrows):
    axes[i][0].imshow(np.reshape(x_val[2*i], (496, 768)), cmap='Greys_r')
    axes[i][1].imshow(np.reshape(y_val[2*i], (496, 768)), cmap='Greys_r')
    axes[i][2].imshow(np.reshape(pred[2*i], (496, 768)), cmap='Greys_r')

plt.show()

# %%
acc = results.history['accuracy']
val_acc = results.history['val_accuracy']
loss = results.history['loss']
val_loss = results.history['val_loss']
epochs = range(1, len(acc) + 1)

fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.plot(epochs, acc, 'ro', label='Training acc')
ax.plot(epochs, val_acc, 'b', label='Validation acc')
ax.set_title('Accuracy with data augmentation', fontsize=22)
ax.set_xlabel(r'Epochs', fontsize=22)
ax.set_ylabel(r'Accuracy', fontsize=22)
ax.tick_params(labelsize=22)
ax.legend(fontsize=24)

figL, axL = plt.subplots(1,1, figsize=(10,6))

axL.plot(epochs, loss, 'ro', label='Training loss')
axL.plot(epochs, val_loss, 'b', label='Validation loss')
axL.set_title('Loss with data augmentation', fontsize=22)
axL.set_xlabel(r'Epochs', fontsize=22)
axL.set_ylabel(r'Loss', fontsize=22)
axL.tick_params(labelsize=22)
axL.legend(fontsize=22)
